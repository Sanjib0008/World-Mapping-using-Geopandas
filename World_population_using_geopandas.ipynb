# %%
import geopandas as gpd

# %%
world_data=gpd.read_file(r"E:\Personal\Training Programme\Python\Datasets\World_Countries.shp")
world_data
# Out:
#                       Country Code  \
# 0                    Zimbabwe  ZWE
# 1                      Zambia  ZMB
# 2                       Yemen  YEM
# 3                     Vietnam  VNM
# 4                   Venezuela  VEN
# ..                        ...  ...
# 235                     Nepal  NPL
# 236                    Bhutan  BTN
# 237                     India  IND
# 238  United States of America  USA
# 239                    Canada  CAN
#
#                                               geometry
# 0    POLYGON ((31.28789 -22.40205, 31.19727 -22.344...
# 1    POLYGON ((30.39609 -15.64307, 30.25068 -15.643...
# 2    MULTIPOLYGON (((53.08564 16.64839, 52.58145 16...
# 3    MULTIPOLYGON (((106.61748 8.68281, 106.58926 8...
# 4    MULTIPOLYGON (((-60.82119 9.13838, -60.94141 9...
# ..                                                 ...
# 235  MULTIPOLYGON (((88.04064 27.21668, 88.04063 27...
# 236  POLYGON ((91.63448 27.85062, 91.63361 27.85072...
# ...

# %%
world_data.plot()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

f, ax =plt.subplots(1,1,figsize=(10,10))
world_data.plot(ax=ax, column='Code', cmap='tab10')
ax.set_title('World Map', fontsize=15)
# Out:
# Text(0.5, 1.0, 'World Map')

# %%
f, ax =plt.subplots(1,1,figsize=(10,10))
world_data.plot(ax=ax, cmap='RdYlGn')
ax.set_title('World Map in diverging pattern')
# Out:
# Text(0.5, 1.0, 'World Map in diverging pattern')

# %%
### 2nd World data
world=gpd.read_file(r'E:\Personal\Training Programme\Python\Datasets\World_Countries_with_population.shp')

# %%
world.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 76 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   featurecla  177 non-null    object
#  1   scalerank   177 non-null    int32
#  2   LABELRANK   177 non-null    int32
#  3   SOVEREIGNT  177 non-null    object
#  4   SOV_A3      177 non-null    object
#  5   ADM0_DIF    177 non-null    int32
#  6   LEVEL       177 non-null    int32
#  7   TYPE        177 non-null    object
#  8   TLC         176 non-null    object
#  9   ADMIN       177 non-null    object
#  10  ADM0_A3     177 non-null    object
#  11  GU_A3       177 non-null    object
#  12  SU_DIF      177 non-null    int32
#  13  SUBUNIT     177 non-null    object
#  14  SU_A3       177 non-null    object
#  15  BRK_DIFF    177 non-null    int32
#  16  NAME        177 non-null    object
#  17  NAME_LONG   177 non-null    object
#  18  BRK_A3      177 non-null    object
# ...

# %%
world.plot()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

f, ax = plt.subplots(1, 1, figsize=(10, 10))
world.plot(ax=ax, column='CONTINENT', cmap='tab10',legend=True, legend_kwds={'loc': 'lower left'})
plt.title('World Map Colored by Continent')
plt.show()

# %%
f, ax =plt.subplots(1,1,figsize=(10,10))
world.plot(ax=ax, column='POP_EST', cmap='RdYlGn_r', legend=True)
ax.set_title('High Density Populated Country')
# Out:
# Text(0.5, 1.0, 'High Density Populated Country')

# %%
from matplotlib.colors import LogNorm

norm=LogNorm(vmin=world.POP_EST.min(),
             vmax=world.POP_EST.max())
f, ax =plt.subplots(1,1,figsize=(10,10))
world.plot(ax=ax, column='POP_EST', cmap='RdYlGn_r', edgecolor='w', linewidth=0.2,
            norm=norm)
ax.axis('off')
ax.set_title("Population Per Country", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Population Per Country')
